# %%
import re
import pandas as pd
pd.options.display.max_seq_items = 4000
pd.options.display.max_rows = 4000
pd.options.display.max_columns = 4000
pd.set_option('display.max_rows', 1000)

# %%
filename = 'fake_job_postings.csv'
job_df = pd.read_csv(filename)

# %%
job_df.department.fillna('unspecified', inplace = True)
job_df.required_education.fillna('Unspecified', inplace = True)
job_df.required_experience.fillna('Unspecified', inplace = True)

# %%
job_df['has_salary_range'] = job_df.salary_range.notnull().astype('int')

# %%
job_df.drop('salary_range', axis = 1, inplace = True)

# %%
pd.DataFrame(job_df.isnull().sum()).T
# Out:
#    job_id  title  location  department  company_profile  description  \
# 0       0      0       346           0             3308            1
#
#    requirements  benefits  telecommuting  has_company_logo  has_questions  \
# 0          2695      7210              0                 0              0
#
#    employment_type  required_experience  required_education  industry  \
# 0             3471                    0                   0      4903
#
#    function  fraudulent  has_salary_range
# 0      6455           0                 0

# %%
df = job_df.dropna(axis = 0)
df.shape
# Out:
# (5822, 18)

# %%
df.groupby(df.fraudulent).count()
# Out:
#             job_id  title  location  department  company_profile  description  \
# fraudulent
# 0             5633   5633      5633        5633             5633         5633
# 1              189    189       189         189              189          189
#
#             requirements  benefits  telecommuting  has_company_logo  \
# fraudulent
# 0                   5633      5633           5633              5633
# 1                    189       189            189               189
#
#             has_questions  employment_type  required_experience  \
# fraudulent
# 0                    5633             5633                 5633
# 1                     189              189                  189
#
#             required_education  industry  function  has_salary_range
# fraudulent
# 0                         5633      5633      5633              5633
# 1                          189       189       189               189

# %%
job_df.required_experience.value_counts()
# Out:
# Unspecified         7050
# Mid-Senior level    3809
# Entry level         2697
# Associate           2297
# Not Applicable      1116
# Director             389
# Internship           381
# Executive            141
# Name: required_experience, dtype: int64

# %%
df.location.value_counts()
# Out:
# GB, LND, London            356
# US, NY, New York           203
# GR, I, Athens              182
# US, CA, San Francisco      182
# NZ, N, Auckland            141
#                           ...
# US, NY, Alfred               1
# US, CA, Arcata               1
# US, IL, Illinois             1
# GR, I, Acharnes, Athens      1
# GB, RIC, London              1
# Name: location, Length: 1232, dtype: int64

# %%
df.location = df.location.replace(to_replace='[A-Za-z]+,|,|\s+', value='', regex=True)

# %%
list = df.location.tolist()

# %%
set(list)
# Out:
# {'',
#  '00MandaluyongCity',
#  '00Manila',
#  '00NorthgateAlabang',
#  '00Philippies',
#  '00QUEZONCITY',
#  '00TaguigCity',
#  '00makati',
#  '01',
#  '01Olaya',
#  '01Singapore',
#  '02',
#  '03Oslo',
#  '05AlHufuf',
#  '07BayanLepas',
#  '10010',
#  '10969',
#  '10Bangkok',
#  '10KUALALUMPUR',
#  '11AlHasa',
#  '11Lisbon',
#  '12Banbuathong',
#  '12PhnomPhen',
#  '13',
#  '13Lumlukka',
#  '13Porto',
#  '13Tokyo-Shibuya',
#  '14KL-PetalingJaya',
#  '1Reykjavik',
#  '23',
#  '23Sofia',
#  '25Milan',
#  '25Milano',
#  '34',
#  '34Istanbul',
#  '37Tallinn',
#  '6Pese',
#  '71Cherkassy',
#  '8',
#  '82AarhusC',
#  '84Copenhagen',
#  '84CopenhagenØ',
#  '84KøbenhavnØ',
#  '84copenhagen',
#  '8Panama',
#  'AMERSFOORT',
#  'ARLINGTON',
#  'ATHENS',
#  'AUS/SAT',
#  'AUSTIN',
#  'Aberdeen',
#  'Aberdeenshire',
#  'Abudhabi',
#  'Accra',
#  'Acharnai',
#  'Acharnes',
#  'Addison',
#  'AgiaParaskevi',
#  'Ahens',
#  'AixenProvence',
#  'Akron',
#  'AlNashwa',
#  'Alamosa',
#  'Albany',
#  'Alexandria',
#  'Alfred',
#  'Alimos',
#  'AllendaleCharterTownship',
#  'Allentown',
#  'Alsip',
#  'Amersfoort',
#  'Ames',
#  'Amherst',
#  'Amsterdam',
#  'Anderson',
#  'AnnArbor',
#  'Antwerpen',
#  'Arcadia',
#  'Arcata',
#  'Arlington',
#  'Artarmon',
#  'Asheville',
#  'Ashland',
#  'Assen',
#  'Athena',
#  'Athens',
#  'Athens(Iraklio)',
#  'Atlanta',
#  'Atlanta-Covington',
#  'AtlantaGa',
#  'Auburn',
#  'AuburnHills',
#  'Auc',
#  'Auckland',
#  'Auckland/Penrose',
#  'Augusta',
#  'Aurora',
#  'Austin',
#  'Austin(orremote)',
#  'BARNSLEY',
#  'Bailtmore',
#  'Bakersfield',
#  'Baltimore',
#  'Baltimore/Columbia',
#  'Bangalore',
#  'Barcelona',
#  'Barrington',
#  'Basingstoke',
#  'Bath',
#  'Batley',
#  'BatonRouge',
#  'BayArea',
#  'Beaufort',
#  'BeaverFalls',
#  'Beckley',
#  'Bedfordshire',
#  'Belfast',
#  'Bellevue',
#  'Bellingham',
#  'Bemidji',
#  'Bend',
#  'Bengaluru',
#  'Berea',
#  'Berkeley',
#  'Berlin',
#  'Berlin/Malaysia',
#  'Bethany',
#  'Bethesda',
#  'BeverlyHills',
#  'Binghampton',
#  'Birmingham',
#  'Bishopsgate',
#  'Bismarck',
#  'Blackpool',
#  'Blacksburg',
#  'Bloomington',
#  'Bloomsburg',
#  'Bluffton',
#  'BocaRaton',
#  'Boise',
#  'Boone',
#  'Boston',
#  'Boulder',
#  'Bournemouth',
#  'BowlingGreen',
#  'Bozeman',
#  'Br',
#  'Bradford',
#  'Bridgewater',
#  'Brighouse',
#  'Bristol',
#  'Bronx',
#  'Brookings',
#  'Brooklyn',
#  'Brookyn',
#  'Broomfield',
#  'Brownsville',
#  'Brunswick',
#  'Brussels',
#  'Bruxelles',
#  'Bryan',
#  'Bucharest',
#  'Buckhannon',
#  'Budapest',
#  'Buffalo',
#  'Burbank',
#  'Burleson',
#  'Burlingame',
#  'Burlington',
#  'CA',
#  'CA/Mt.Poso',
#  'CHENNAI',
#  'CORALSPRINGS',
#  'Cairo',
#  'Calgary',
#  'California',
#  'Camberley',
#  'Cambridge',
#  'CanaryWharf',
#  'Cantebury',
#  'Canterbury',
#  'Canton',
#  'Carbondale',
#  'Carlsb',
#  'Carlsbad',
#  'Carlton',
#  'Carmel',
#  'Carrollton',
#  'Casper',
#  'CedarFalls',
#  'CedarRapids',
#  'Celina',
#  'Central/SouthernMinnesota',
#  'CentralBirmingham',
#  'CentralLodon',
#  'CentralLondon',
#  'CentralNJPreferred',
#  'Chalandri',
#  'Chamberi|Madrid',
#  'Champaign',
#  'Champaigne',
#  'Chandler',
#  'Chania',
#  'ChapelHill',
#  'Charleston',
#  'Charlotte',
#  'Charlottesville',
#  'Chattanooga',
#  'Chautauqua',
#  'Cheadle',
#  'Chelmsford',
#  'Cheney',
#  'Chennai',
#  'Chesapeake',
#  'Chester',
#  'ChestnutHill',
#  'Chicago',
#  'Chico',
#  'ChulaVista',
#  'Cimahi',
#  'Cincinnati',
#  'City',
#  'Claremont',
#  'Clarion',
#  'ClearLake',
#  'Clemmons',
#  'Clemson',
#  'Clevedon',
#  'Cleveland',
#  'Cocoa',
#  'Colchester',
#  'College',
#  'CollegePark',
#  'CollegeStation',
#  'Colombo',
#  'ColoradoSprings',
#  'Columbia',
#  'Columbus',
#  'Commack',
#  'Concord',
#  'Conway',
#  'CoonRapids',
#  'Cooperstown',
#  'Copenhagen',
#  'CoralSprings',
#  'CorfeCastle',
#  'Cornwall',
#  'CorpusChristi',
#  'Corsicana',
#  'Cortland',
#  'Corvallis',
#  'CottageGrove',
#  'CouncilBluffs',
#  'Coventry',
#  'Crewe',
#  'Cullowhee',
#  'Cupertino',
#  'DALLAS',
#  'DC',
#  'DCMetro',
#  'DE',
#  'DEARBORN',
#  'DFW',
#  'Dallas',
#  'Dallas/FortWorth',
#  'Dallas/Ft.Worth',
#  'Danbury',
#  'Danvers',
#  'Danville',
#  'Davenport',
#  'Davidson',
#  'Dayton',
#  'Decatur',
#  'Deerfield',
#  'Delaware',
#  'Delhi',
#  'Denton',
#  'Denver',
#  'Detroit',
#  'Dewsbury',
#  'DiamondBar',
#  'Dickinson',
#  'DistrictofColumbia',
#  'Doha',
#  'Dortmund',
#  'Draper',
#  'Dubai',
#  'Dublin',
#  'Dubuque',
#  'Duluth',
#  'Dundee',
#  'Durango',
#  'Durham',
#  'EastLansing',
#  'EastPeoria',
#  'EastStroudsburg',
#  'EasternUS',
#  'EauClaire',
#  'Ebene',
#  'Edinboro',
#  'Edinburgh',
#  'Edison',
#  'Edmond',
#  'Edmonton',
#  'Eindhoven',
#  'Ellensburg',
#  'Ellenville',
#  'Elmira',
#  'Elmsford',
#  'Elon',
#  'Elroy',
#  'Emeryville',
#  'Encino',
#  'Essex',
#  'Ettrick',
#  'Eugene',
#  'Evanston',
#  'Evansville',
#  'Everett',
#  'FORTWORTH',
#  'Fairfax',
#  'FairfaxArea',
#  'Fairmont',
#  'Fargo',
#  'FargoorBismarck',
#  'Faribault',
#  'Farmingdale',
#  'FarmingtonHills',
#  'Fayetteville',
#  'Feltham',
#  'Finchley',
#  'FingerLakes',
#  'Fishers',
#  'Flagstaff',
#  'Flint',
#  'Florence',
#  'Florida',
#  'Flushing',
#  'FortCollins',
#  'FortLauderdale',
#  'FortWayne',
#  'FortWorth',
#  'FourWays',
#  'Frankfurt',
#  'Franksville',
#  'Fredericksburg',
#  'Fredonia',
#  'Freehold',
#  'Fresno',
#  'Frostburg',
#  'Ft.Benning',
#  'Fulham',
#  'Fullerton',
#  'GB',
#  'GREENVILLE',
#  'Gainesville',
#  'Gaithersburg',
#  'GardenGrove',
#  'Gardena',
#  'Garland',
#  'Gdańsk',
#  'Georgia',
#  'Ghent',
#  'Gilbert',
#  'GilroyHollister',
#  'Gladstone',
#  'Glasgow',
#  'Glasgow/Birmingham/London/Remote',
#  'GlendaleHeights',
#  'Glendaleheights',
#  'Glyfada',
#  'GoldenValley',
#  'GrandForks',
#  'GrandIsland',
#  'GrandPrairie',
#  'GrandRapids',
#  'GreaterBoston',
#  'GreaterLosAngelesArea',
#  'Greencastle',
#  'Greensboro',
#  'Greenville',
#  'Greenwich',
#  'Grinnell',
#  'Gurgaon',
#  'HARTFORD',
#  'HOUSTON',
#  'Hackensack',
#  'Haddonfield',
#  'Halandri',
#  'Halifax',
#  'Hamburg',
#  'Hamilton',
#  'Hammersmith',
#  'Hammond',
#  'Hampton',
#  'Hanley',
#  'Harlan',
#  'Harlingen',
#  'Harrisburg',
#  'Harrisonburg',
#  'Harrogate',
#  'Hartland',
#  'HasbrouckHeights',
#  'Hastings',
#  'Hathersage',
#  'Hattiesburg',
#  'Heidelberg',
#  'Helsinki',
#  'HemelHempstead',
#  'Henderson',
#  'Herndon',
#  'Hessle',
#  'Hidalgo',
#  'HighlandHeights',
#  'Hilliard',
#  'Hillsboro',
#  'Hilversum',
#  'Hoboken',
#  'Hollywood',
#  'HongKong',
#  'Hopkins',
#  'Horsforth',
#  'Houston',
#  'Hoxton',
#  'Huddersfield',
#  'HudsonValley',
#  'Huntingdon',
#  'Huntington',
#  'HuntingtonBeach',
#  'Hyderabad',
#  'Ilion',
#  'Illinois',
#  'Indiana',
#  'Indianapolis',
#  'Indore',
#  'Insch',
#  'IowaCity',
#  'Iowacity',
#  'Irakleio',
#  'Iraklio',
#  'Irvine',
#  'Irving',
#  'IslaVista',
#  'Istanbul',
#  'Ithaca',
#  'Jackson',
#  'Jacksonville',
#  'Jakarta',
#  'Jamison',
#  'Janesville',
#  'JeffersonCity',
#  'JerseyCity',
#  'Johannesburg',
#  'Jonesboro',
#  'Juman',
#  'Juneau',
#  'Juárez',
#  'Kalamazoo',
#  'KansasCity',
#  'Karachi',
#  'Keene',
#  'KellerandBurleson',
#  'Kelowna',
#  'Kent',
#  'Kettering',
#  'Kifisia',
#  'Killeen',
#  'Kingston',
#  'KingstonuponThames',
#  'Kingswinford',
#  'Kirkland',
#  'Kirksville',
#  'Knoxville',
#  'Komotini',
#  'Krakow',
#  'KualaLumpur-Sentral',
#  'Kutztown',
#  'LONDON',
#  'LaMirada',
#  'Lafayette',
#  'Lahore',
#  'LakeCity',
#  'LakeOswego',
#  'Lakeland',
#  'Lakeport',
#  'Langley',
#  'Langston',
#  'Lanham',
#  'Lansing',
#  'Laramie',
#  'Laredo',
#  'LasCruces',
#  'LasVegas',
#  'Lassi',
#  'Lasvegas',
#  'Launceston',
#  'Lawrence',
#  'Leeds',
#  'Leesburg',
#  'Leicester',
#  'Leipzig',
#  'Lekki',
#  'Leuven',
#  'Levittown',
#  'Lewisburg',
#  'Lexington',
#  'Leyton',
#  'Liberty',
#  'Libertyville',
#  'Lincoln',
#  'LittleRock',
#  'Livingston',
#  'Livonia',
#  'LockHaven',
#  'Logan',
#  'London',
#  'LondonBridge',
#  'LongBeach',
#  'LongIsland',
#  'LongIslandCity',
#  'LosAngeles',
#  'Louisville',
#  'Lubbock',
#  'Luton',
#  'Luxembourg',
#  'Lynwood',
#  'MANASSAS',
#  'Maadi',
#  'Macclesfield',
#  'Macomb',
#  'Macon',
#  'Madison',
#  'Madrid',
#  'Maidenhead',
#  'MakatiCity',
#  'Malden',
#  'Managua',
#  'Manchester',
#  'Manhattan',
#  'ManhattanBeach',
#  'Mankato',
#  'Mansfield',
#  'MapleGrove',
#  'MarcellusPawPawLawton',
#  'Marin',
#  'MarinaDelRey',
#  'MarinadelRey',
#  'Marion',
#  'Marlborough',
#  'Marlow',
#  'Marousi',
#  'Marousi-Athens',
#  'Marshall',
#  'Martin',
#  'Maryland/D.C.Area',
#  'Mason',
#  'MasonCity',
#  'Massachusetts',
#  'MayfieldVillage',
#  'McAllen',
#  'McLean',
#  'Meanwood',
#  'Meas/Chandler/Gilbert',
#  'Mechanicsburg',
#  'Mechelen',
#  'Medford',
#  'MediaCity|Dubai',
#  'Meigle',
#  'Melbourne',
#  'Menlo',
#  'MenloPark',
#  'Menomonie',
#  'Mentor',
#  'Merrillville',
#  'Mesa',
#  'Mesa/Chandler',
#  'Mexico',
#  'MexicoCity',
#  'Miami',
#  'Middlesex',
#  'MilanArea',
#  'Millersville',
#  'MiltonKeynes',
#  'Milwaukee',
#  'Milwaukie',
#  'Minden',
#  'Minneapolis',
#  'Minnetonka',
#  'Miramar',
#  'Missoula',
#  'Monroe',
#  'Monterey',
#  'Monterrey',
#  'Montevallo',
#  'Montpellier',
#  'Montreal',
#  'Moorehead',
#  'Moorhead',
#  'Morgantown',
#  'Moscow',
#  'MountPleasant',
#  'MountainView',
#  'Mt.Pleasant',
#  'Muncie',
#  'Mundelein',
#  'Munich',
#  'Murfreesboro',
#  'Murray',
#  'Mykonos',
#  'México',
#  'München',
#  'N.Irakleio',
#  'NEPortland',
#  'NOTTINGHAM',
#  'NWHouston',
#  'NWPortland&Hillsboro',
#  'NY',
#  'NZ',
#  'Napanoch',
#  'Nashville',
#  'NasrCity',
#  'Natchitoches',
#  'NeaFiladelfia',
#  'NeoAthens',
#  'NeoIrakleio',
#  'NeoIraklio',
#  'NewBraunfels',
#  'NewBritain',
#  'NewBrunswick',
#  'NewCastle',
#  'NewDelhi',
#  'NewHaven',
#  'NewHudson',
#  'NewJersey',
#  'NewOrleans',
#  'NewPaltz',
#  'NewYork',
#  'NewYork/Boston',
#  'NewYorkCity',
#  'NewYorkMetro',
#  'Newark',
#  'Newcastle',
#  'NewcastleUponTyne',
#  'NewportBeach',
#  'Niles',
#  'Noida',
#  'Norman',
#  'NorthDallas',
#  'NorthEast',
#  'NorthHollywood',
#  'NorthPortland',
#  'NorthSydney',
#  'NorthYork',
#  'Northampton',
#  'Northbrook',
#  'Northfield',
#  'Northumberland',
#  'NotreDame',
#  'NottingHill',
#  'Nottingham',
#  'NoviSad',
#  'OKLAHOMACITY',
#  'OakBrook',
#  'Oakland',
#  'Oberlin',
#  'OklahomaCity',
#  'Omaha',
#  'Oneonta',
#  'Ontario',
#  'Orange',
#  'OrangeCounty',
#  'OrlandPark',
#  'Orlando',
#  'Orono',
#  'Oshkosh',
#  'Ossett',
#  'Oswego',
#  'Otisville',
#  'Ottawa',
#  'OverlandPark',
#  'Oxford',
#  'PHILADELPHIA',
#  'PLANO',
#  'PalmSprings',
#  'PaloAlto',
#  'Paris',
#  'Parma',
#  'Parsippany',
#  'Pasadena',
#  'Pascagoula',
#  'Patra',
#  'Patras',
#  'PawPaw',
#  'PearlHarbor',
#  'Peekskill',
#  'Pembroke',
#  'Penrith',
#  'Peoria',
#  'PerthandKinross',
#  'Perthshire',
#  'Philadelphia',
#  'Philippi',
#  'Philippines',
#  'Phoenix',
#  'Phoneix',
#  'Picacho',
#  'Piraeus',
#  'Pireaus',
#  'Piscataway',
#  'Pittsburgh',
#  'Plano',
#  'Plantation',
#  'Plattsburgh',
#  'Pleasanton',
#  'Pleasonton',
#  'Plymouth',
#  'PointLookout',
#  'PompanoBeach',
#  'Porland',
#  'PortCharlotte',
#  'Portand',
#  'Portland',
#  'Portland/Hillsboro',
#  'Porto',
#  'Portsmouth',
#  'Potsdam',
#  'Poughkeepsie',
#  'Poznań',
#  'Preston',
#  'Princeton',
#  'Provo',
#  'Pullman',
#  'Pune',
#  'Putney',
#  'QUEZONCITY',
#  'Queens',
#  'Querétaro',
#  'REMOTE',
#  'RacineArea',
#  'Radford',
#  'Raleigh',
#  'Ravenna',
#  'Reading',
#  'RedDeer',
#  'Redlands',
#  'Remote',
#  'Reno',
#  'Reston',
#  'Rexburg',
#  'RichardsBay',
#  'Richmond',
#  'Riga',
#  'Rindge',
#  'Ringgold',
#  'RioDeJaneiro',
#  'RiverFalls',
#  'RiversideCoutny',
#  'RobinsonTownship',
#  'Rochester',
#  'RockHill',
#  'RockvilleCentre',
#  'Rome',
#  'Rosemead',
#  'Roseville',
#  'Rotterdam',
#  'RoyalOak',
#  'Rusholme',
#  'Ruston',
#  'Rye',
#  'SEHouston',
#  'SEPortland',
#  'SWPortland',
#  'Sacaramento',
#  'Sacramento',
#  'SaintPaul',
#  'Sale',
#  'Salem',
#  'Salford',
#  'Salinas',
#  'Salisbury',
#  'SaltLakeCity',
#  'Saltillo',
#  'San',
#  'SanAntonio',
#  'SanCA',
#  'SanCarlos',
#  'SanDiego',
#  'SanDiego/OrangeCounty',
#  'SanDigeo',
#  'SanFrancisco',
#  'SanFranciscoBayArea',
#  'SanFranscisco',
#  'SanJose',
#  'SanLuisObispo',
#  'SanMateo',
#  'SanRamon',
#  'Sandy',
#  'SantaClara',
#  'SantaCruz',
#  'SantaMonica',
#  'SantaRosa',
#  'SaoPaulo',
#  'SaratogaSprings',
#  'Savage',
#  'Scarborough',
#  'Scottsdale',
#  'Scottsdale/Phoenix',
#  'Scranton',
#  'Seattle',
#  'SeetheRequirementssectionforareasandlocationsavailable',
#  'Selinsgrove',
#  'Seneca',
#  'SevenHills',
#  'Sewell',
#  'Shepherdstown',
#  'Shippensburg',
#  'Shoreditch',
#  'Sidney',
#  'Singapore',
#  'SiouxFalls',
#  'SlipperyRock',
#  'Sofia',
#  'SouthBend',
#  'SouthSanFrancisco',
#  'SouthYorkshire',
#  'Southampton',
#  'Spicewood',
#  'SpringHill',
#  'Springfield',
#  'St.Bonaventure',
#  'St.Cloud',
#  'St.Louis',
#  'St.Paul',
#  'St.Petersburg',
#  'StLouis',
#  'StPaul',
#  'Stafford',
#  'Staffordshire',
#  'Stanford',
#  'Starkville',
#  'Statewide',
#  'Stockholm',
#  'Stockton-On-Tees',
#  'Sunnyvale',
#  'Surbiton',
#  'SurryHills',
#  'Suwanee',
#  'Swindon',
#  'Sydney',
#  'Syracuse',
#  'SãoPaulo',
#  'TULSA',
#  'TaguigCity',
#  'Taipei',
#  'Tampa',
#  'Teddington',
#  'Tel-Aviv',
#  'Temecula',
#  'Tempe',
#  'Temple',
#  'TheHague',
#  'Thessaloniki',
#  'Tigard',
#  'Tokyo-Shibuya',
#  'Toronto',
#  'Torrance',
#  'Totowa',
#  'Trenton',
#  'Trivandrum',
#  'Troy',
#  'Tulsa',
#  'TwinCities',
#  'TysonsCorner',
#  'US',
#  'UnionGrove',
#  'Urmston',
#  'Utica',
#  'Valanciennes',
#  'Valencia',
#  'Valenciennes',
#  'VanWert',
#  'Vancouver',
#  'Vari',
#  'VariousinWestYorkshire',
#  'VirginiaBeach',
#  'Visakhapatnam',
#  'Visby',
#  'Vishakhapatanam',
#  'Volos',
#  'WAUKESHA',
#  'WC1V6PX',
#  'Wakefield',
#  'Warrington',
#  'Warsaw',
#  'Warwick',
#  'Washington',
#  'WashingtonDC',
#  'Waterloo',
#  'Watertown',
#  'Watervliet',
#  'Waucanda',
#  'Waukegan',
#  'Waukesha',
#  'Waynesburg',
#  'Weaverville',
#  'Wel',
#  'Wellington',
#  'WestAllis',
#  'WestCovina',
#  'WestDesMoines',
#  'WestHaven',
#  'WestHollywood',
#  'WestPalmBeach',
#  'WesternUS',
#  'WesternWisconsin',
#  'Westerville',
#  'Weston',
#  'Westport',
#  'Weymouth',
#  'WhitePlains',
#  'Wigan',
#  'Wilmington',
#  'Wimbledon',
#  'Winnipeg',
#  'WinstonSalem',
#  'Woburn',
#  'Woking',
#  'Wolverhampton',
#  'WoodlandHills',
#  'Yankton',
#  'YorbaLinda',
#  'Zurich',
#  'Zürich',
#  'auckland',
#  'bangalore',
#  'bedfordshire',
#  'berlin',
#  'ca',
#  'caulfield',
#  'chalandri',
#  'chicago',
#  'dallas',
#  'denver',
#  'kent',
#  'knoxville',
#  'leeds',
#  'liverpool',
#  'lo',
#  'london',
#  'louisville',
#  'miami',
#  'milwaukee',
#  'newyork',
#  'ravenna',
#  'sandiego',
#  'sanfrancisco',
#  'sydney',
#  'Αthens',
#  'Αθήνα'}
